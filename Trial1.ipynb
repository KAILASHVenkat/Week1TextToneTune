# %% [markdown]
# <a href="https://colab.research.google.com/github/KAILASHVenkat/Week1TextToneTune/blob/main/Trial1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
model=LogisticRegression(max_iter=1990)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9ab5efbb-63d6-4420-992a-99c43292ee73" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9ab5efbb-63d6-4420-992a-99c43292ee73">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('drug200.csv')

# %%
df[0:5]
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %%
Sex_Mapping={"M":0,"F":1}
df["Sex"]=df["Sex"].map(Sex_Mapping)
bp_map={"HIGH":2,"NORMAL":1,"LOW":0}
df["BP"]=df["BP"].map(bp_map)
c_map={"HIGH":1,"NORMAL":0}
df["Cholesterol"]=df["Cholesterol"].map(c_map)
d_map={"DrugY":0,"drugA":1,"drugB":2,"drugC":3,"drugX":4}
df["Drug"]=df["Drug"].map(d_map)
df
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K  Drug
# 0     23    1   2            1   25.355     0
# 1     47    0   0            1   13.093     3
# 2     47    0   0            1   10.114     3
# 3     28    1   1            1    7.798     4
# 4     61    1   0            1   18.043     0
# ..   ...  ...  ..          ...      ...   ...
# 195   56    1   0            1   11.567     3
# 196   16    0   0            1   12.006     3
# 197   52    0   1            1    9.894     4
# 198   23    0   1            0   14.020     4
# 199   40    1   0            0   11.349     4
#
# [200 rows x 6 columns]

# %%
df.Drug.unique()
# Out:
# array([0, 3, 4, 1, 2])

# %%
from sklearn.model_selection import train_test_split

# %%
x=df[['Age','Sex','BP','Cholesterol','Na_to_K']]
y=df['Drug']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1990)

# %%
model.score(x_test,y_test)
# Out:
# 0.95
